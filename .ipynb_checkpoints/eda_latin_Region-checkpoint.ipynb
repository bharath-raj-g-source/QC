# %%
import pandas as pd
import os

# --- 1. Load the DataFrame (as specified) ---

# Define the file path (adjust 'data/' if needed based on your notebook location)
# NOTE: This line assumes you have the file "data/WF 3 F1-R12 - Great Britain.xlsx"
file_path = "data/WF 3 F1-R12 - Great Britain.xlsx"

try:
    df = pd.read_excel(
        file_path,
        sheet_name="Worksheet",
        header=5 
    )
    print("✅ DataFrame successfully loaded.")
    # print("\n--- Initial DataFrame Head ---\n")
    # print(df.head())
    # print("\n------------------------------\n")

except FileNotFoundError:
    print(f"❌ Error: File not found at '{file_path}'. Please ensure the file exists and the path is correct.")
    # Create an empty DF for the function definition below to run without error
    df = pd.DataFrame() 


# --- 2. Convert the function to Standalone ---

def check_latam_espn_channels(input_df: pd.DataFrame) -> pd.DataFrame:
    """
    CHECK 1: Channel and Territory Review
    Checks the LATAM region for markets expected to have ESPN channels 
    but where no ESPN data exists, flagging common omissions.
    
    Args:
        input_df: The BSR DataFrame to check.
        
    Returns:
        The input DataFrame with 'LATAM_ESPN_Check_OK' and 
        'LATAM_ESPN_Remark' columns added.
    """
    if input_df.empty:
        print("⚠️ Warning: Input DataFrame is empty. Returning an empty DataFrame.")
        return input_df

    print("ACTION: Running LATAM ESPN Channels check (flagging missing markets).")
    df = input_df.copy()

    # --- 1. Define the LATAM Scope ---
    # Look for regions that contain 'America' (Central and South America is in your initial data)
    latam_region_mask = df.get('Region', '').astype(str).str.contains(
        r'central.*america|south.*america|latin america|latam', case=False, na=False
    )
    # Check if 'Region' column exists before filtering
    if latam_region_mask.empty:
        print("❌ Error: 'Region' column not found in DataFrame. Skipping check.")
        df['LATAM_ESPN_Check_OK'] = True
        df['LATAM_ESPN_Remark'] = "Skipped: 'Region' column missing."
        return df
        
    latam_df = df[latam_region_mask].copy()

    # Define the set of all unique markets (countries) found in the LATAM region
    all_latam_markets = set(latam_df.get('Market', '').dropna().astype(str).str.strip().unique())

    # Define the set of markets that *do* have ESPN listed
    espn_mask = latam_df.get('Broadcaster', '').astype(str).str.contains(r'espn', case=False, na=False)
    markets_with_espn = set(latam_df[espn_mask].get('Market', '').dropna().astype(str).str.strip().unique())

    # --- 2. Identify Missing Markets ---
    # Markets that are in LATAM but have no records for the 'ESPN' broadcaster
    missing_espn_markets = all_latam_markets - markets_with_espn

    print(f"Total LATAM Markets found: {len(all_latam_markets)}")
    print(f"Markets with ESPN data: {len(markets_with_espn)}")
    print(f"⚠️ Markets missing ESPN data: {missing_espn_markets}")
    
    # --- 3. Update the full DF with QC columns ---
    
    # Initialize all rows to OK
    df['LATAM_ESPN_Check_OK'] = True
    df['LATAM_ESPN_Remark'] = "OK"

    # Mark the rows that belong to the markets flagged
    flag_mask = df.get('Market', '').astype(str).str.strip().isin(missing_espn_markets)
    
    if flag_mask.any():
        df.loc[flag_mask, 'LATAM_ESPN_Check_OK'] = False
        df.loc[flag_mask, 'LATAM_ESPN_Remark'] = "Market has no ESPN data (Expected in LATAM region)."

    # The auxiliary DataFrame self.missing_latam_espn_df is no longer needed in the standalone version
    # The processed dataframe is returned.
    return df


# --- 3. Run the Function and Print the Result ---

if not df.empty:
    df_processed = check_latam_espn_channels(df)

    print("\n====================================")
    print("✅ Final Processed DataFrame Output")
    print("====================================\n")
    
    # Show the tail to easily see the new QC columns
    print(df_processed.tail()) 
    
    # Show only the flagged rows for verification (if any)
    flagged_rows = df_processed[df_processed['LATAM_ESPN_Check_OK'] == False]
    
    if not flagged_rows.empty:
        print("\n--- Flagged Rows (LATAM ESPN Missing) ---\n")
        print(flagged_rows)
    else:
        print("\n--- No LATAM ESPN markets were flagged in this dataset. ---\n")
else:
    print("Cannot proceed with the check as the DataFrame could not be loaded.")
# Out:
# ✅ DataFrame successfully loaded.
#
# --- Initial DataFrame Head ---
#
#                       Region     Market  Market ID Broadcaster  \
# 0  Central and South America  Argentina       74.0        ESPN
# 1  Central and South America  Argentina       74.0    Mediapro
# 2  Central and South America  Argentina       74.0    Mediapro
# 3  Central and South America  Argentina       74.0    Mediapro
# 4  Central and South America  Argentina       74.0    Mediapro
#
#          TV-Channel  Channel ID Pay/Free TV Date (UTC/GMT)       Date  \
# 0        ESPN 2 ARG      1210.0         NaN     2025-07-04 2025-07-03
# 1  Fox Sports (ARG)      2732.0         NaN     2025-07-04 2025-07-04
# 2  Fox Sports (ARG)      2732.0         NaN     2025-07-04 2025-07-04
# 3  Fox Sports (ARG)      2732.0         NaN     2025-07-05 2025-07-04
# 4  Fox Sports (ARG)      2732.0         NaN     2025-07-05 2025-07-04
#
#                    Day  ... Spot price in Euro [1 sec.] Fixture analysis  \
# 0  2025-07-03 00:00:00  ...                         NaN              NaN
# 1  2025-07-04 00:00:00  ...                         NaN              NaN
# 2  2025-07-04 00:00:00  ...                         NaN              NaN
# 3  2025-07-04 00:00:00  ...                         NaN              NaN
# 4  2025-07-04 00:00:00  ...                         NaN              NaN
#
#   Brandbase upload Source BT Start BT Duration Unnamed: 43 Unnamed: 44  \
# 0              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1              NaN  IBOPE      NaN         NaN         NaN         NaN
# 2              NaN  IBOPE      NaN         NaN         NaN         NaN
# 3              NaN  IBOPE      NaN         NaN         NaN         NaN
# 4              NaN  IBOPE      NaN         NaN         NaN         NaN
#
#   Unnamed: 45 Unnamed: 46
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 47 columns]
#
# ------------------------------
#
# ACTION: Running LATAM ESPN Channels check (flagging missing markets).
# Total LATAM Markets found: 12
# Markets with ESPN data: 10
# ⚠️ Markets missing ESPN data: {'Brazil', 'Mexico'}
#
# ====================================
# ✅ Final Processed DataFrame Output
# ====================================
#
#       Region      Market  Market ID Broadcaster TV-Channel  Channel ID  \
# 2955  Global  Pan-Global        NaN         NaN    YouTube         NaN
# 2956  Global  Pan-Global        NaN         NaN    YouTube         NaN
# 2957  Global  Pan-Global        NaN         NaN    YouTube         NaN
# 2958  Global  Pan-Global        NaN         NaN    YouTube         NaN
# 2959  Global  Pan-Global        NaN         NaN        NaN         NaN
#
#      Pay/Free TV Date (UTC/GMT)       Date  Day  ... Brandbase upload Source  \
# 2955         NaN     2025-07-04 2025-07-04  NaN  ...              NaN    NaN
# 2956         NaN     2025-07-05 2025-07-05  NaN  ...              NaN    NaN
# 2957         NaN     2025-07-05 2025-07-05  NaN  ...              NaN    NaN
# 2958         NaN     2025-07-06 2025-07-06  NaN  ...              NaN    NaN
# 2959         NaN            NaT        NaT  NaN  ...              NaN    NaN
#
#      BT Start BT Duration Unnamed: 43 Unnamed: 44 Unnamed: 45 Unnamed: 
2025-07-04 2025-07-04  2025-07-04 00:00:00  ...
# 1449         OTT     2025-07-04 2025-07-04  2025-07-04 00:00:00  ...
# 1450         OTT     2025-07-05 2025-07-05  2025-07-05 00:00:00  ...
# 1451         OTT     2025-07-05 2025-07-05  2025-07-05 00:00:00  ...
# 1452         OTT     2025-07-06 2025-07-06  2025-07-06 00:00:00  ...
# 2749         NaN     2025-07-06 2025-07-06  2025-07-05 00:00:00  ...
# 2854         NaN     2025-07-04 2025-07-04                  NaN  ...
# 2855         NaN     2025-07-04 2025-07-04                  NaN  ...
# 2856         NaN     2025-07-04 2025-07-04                  NaN  ...
# 2857         NaN     2025-07-05 2025-07-05                  NaN  ...
# 2858         NaN     2025-07-05 2025-07-05                  NaN  ...
# 2859         NaN     2025-07-05 2025-07-05                  NaN  ...
# 2860         NaN     2025-07-06 2025-07-06                  NaN  ...
# 2861         NaN     2025-07-05 2025-07-05  2025-07-07 00:00:00  ...
# 2862         NaN     2025-07-06 2025-07-06                  NaN  ...
# 2863         NaN     2025-07-07 2025-07-07                  NaN  ...
#
#      Brandbase upload Source BT Start BT Duration Unnamed: 43 Unnamed: 44  \
# 278               NaN  IBOPE      NaN         NaN         NaN         NaN
# 1415              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1416              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1417              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1418              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1419              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1420              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1421              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1422              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1423              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1424              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1425              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1426              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1427              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1428              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1429              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1430              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1431              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1432              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1433              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1434              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1435              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1436              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1437              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1438              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1439              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1440              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1441              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1442              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1443              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1444              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1445              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1446              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1447              NaN  IBOPE      NaN         NaN         NaN         NaN
# 1448              NaN    BSA      NaN         NaN         NaN         NaN
# 1449              NaN    BSA      NaN         NaN         NaN         NaN
# 1450              NaN    BSA      NaN         NaN         NaN         NaN
# 1451              NaN    BSA      NaN         NaN         NaN         NaN
# 1452              NaN    BSA      NaN         NaN         NaN         NaN
# 2749              NaN    NaN      NaN         NaN         NaN         NaN
# 2854              NaN    NaN      NaN         NaN         NaN         NaN
# 2855              NaN    NaN      NaN         NaN         NaN         NaN
# 2856              NaN    NaN      NaN         NaN         NaN         NaN
# 2857              NaN    NaN      NaN         NaN         NaN         NaN
# 2858              NaN    NaN      NaN         NaN         NaN         NaN
# 2859              NaN    NaN      NaN         NaN         NaN         NaN
# 2860              NaN    NaN      NaN         NaN         NaN         NaN
# 2861              NaN    BSA      NaN         NaN         NaN         NaN
# 2862              NaN    NaN      NaN         NaN         NaN         NaN
# 2863              NaN    NaN      NaN         NaN         NaN         NaN
#
#      Unnamed: 45 Unnamed: 46 LATAM_ESPN_Check_OK  \
# 278          NaN         NaN               False
# 1415         NaN         NaN               False
# 1416         NaN         NaN               False
# 1417         NaN         NaN               False
# 1418         NaN         NaN               False
# 1419         NaN         NaN               False
# 1420         NaN         NaN               False
# 1421         NaN         NaN               False
# 1422         NaN         NaN               False
# 1423         NaN         NaN               False
# 1424         NaN         NaN               False
# 1425         NaN         NaN               False
# 1426         NaN         NaN               False
# 1427         NaN         NaN               False
# 1428         NaN         NaN               False
# 1429         NaN         NaN               False
# 1430         NaN         NaN               False
# 1431         NaN         NaN               False
# 1432         NaN         NaN               False
# 1433         NaN         NaN               False
# 1434         NaN         NaN               False
# 1435         NaN         NaN               False
# 1436         NaN         NaN               False
# 1437         NaN         NaN               False
# 1438         NaN         NaN               False
# 1439         NaN         NaN               False
# 1440         NaN         NaN               False
# 1441         NaN         NaN               False
# 1442         NaN         NaN               False
# 1443         NaN         NaN               False
# 1444         NaN         NaN               False
# 1445         NaN         NaN               False
# 1446         NaN         NaN               False
# 1447         NaN         NaN               False
# 1448         NaN         NaN               False
# 1449         NaN         NaN               False
# 1450         NaN         NaN               False
# 1451         NaN         NaN               False
# 1452         NaN         NaN               False
# 2749         NaN         NaN               False
# 2854         NaN         NaN               False
# 2855         NaN         NaN               False
# 2856         NaN         NaN               False
# 2857         NaN         NaN               False
# 2858         NaN         NaN               False
# 2859         NaN         NaN               False
# 2860         NaN         NaN               False
# 2861         NaN         NaN               False
# 2862         NaN         NaN               False
# 2863         NaN         NaN               False
#
#                                       LATAM_ESPN_Remark
# 278   Market has no ESPN data (Expected in LATAM reg...
# 1415  Market has no ESPN data (Expected in LATAM reg...
# 1416  Market has no ESPN data (Expected in LATAM reg...
# 1417  Market has no ESPN data (Expected in LATAM reg...
# 1418  Market has no ESPN data (Expected in LATAM reg...
# 1419  Market has no ESPN data (Expected in LATAM reg...
# 1420  Market has no ESPN data (Expected in LATAM reg...
# 1421  Market has no ESPN data (Expected in LATAM reg...
# 1422  Market has no ESPN data (Expected in LATAM reg...
# 1423  Market has no ESPN data (Expected in LATAM reg...
# 1424  Market has no ESPN data (Expected in LATAM reg...
# 1425  Market has no ESPN data (Expected in LATAM reg...
# 1426  Market has no ESPN data (Expected in LATAM reg...
# 1427  Market has no ESPN data (Expected in LATAM reg...
# 1428  Market has no ESPN data (Expected in LATAM reg...
# 1429  Market has no ESPN data (Expected in LATAM reg...
# 1430  Market has no ESPN data (Expected in LATAM reg...
# 1431  Market has no ESPN data (Expected in LATAM reg...
# 1432  Market has no ESPN data (Expected in LATAM reg...
# 1433  Market has no ESPN data (Expected in LATAM reg...
# 1434  Market has no ESPN data (Expected in LATAM reg...
# 1435  Market has no ESPN data (Expected in LATAM reg...
# 1436  Market has no ESPN data (Expected in LATAM reg...
# 1437  Market has no ESPN data (Expected in LATAM reg...
# 1438  Market has no ESPN data (Expected in LATAM reg...
# 1439  Market has no ESPN data (Expected in LATAM reg...
# 1440  Market has no ESPN data (Expected in LATAM reg...
# 1441  Market has no ESPN data (Expected in LATAM reg...
# 1442  Market has no ESPN data (Expected in LATAM reg...
# 1443  Market has no ESPN data (Expected in LATAM reg...
# 1444  Market has no ESPN data (Expected in LATAM reg...
# 1445  Market has no ESPN data (Expected in LATAM reg...
# 1446  Market has no ESPN data (Expected in LATAM reg...
# 1447  Market has no ESPN data (Expected in LATAM reg...
# 1448  Market has no ESPN data (Expected in LATAM reg...
# 1449  Market has no ESPN data (Expected in LATAM reg...
# 1450  Market has no ESPN data (Expected in LATAM reg...
# 1451  Market has no ESPN data (Expected in LATAM reg...
# 1452  Market has no ESPN data (Expected in LATAM reg...
# 2749  Market has no ESPN data (Expected in LATAM reg...
# 2854  Market has no ESPN data (Expected in LATAM reg...
# 2855  Market has no ESPN data (Expected in LATAM reg...
# 2856  Market has no ESPN data (Expected in LATAM reg...
# 2857  Market has no ESPN data (Expected in LATAM reg...
# 2858  Market has no ESPN data (Expected in LATAM reg...
# 2859  Market has no ESPN data (Expected in LATAM reg...
# 2860  Market has no ESPN data (Expected in LATAM reg...
# 2861  Market has no ESPN data (Expected in LATAM reg...
# 2862  Market has no ESPN data (Expected in LATAM reg...
# 2863  Market has no ESPN data (Expected in LATAM reg...
#
# [50 rows x 49 columns]
